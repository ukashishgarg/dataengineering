# %% [markdown]
# # Databricks Demo
# ***
# 1. Create source data as JSON (usually get it via data ingestion process as a batch data or stream data)
# 2. Read source data to spark dataframe
# 3. Transformed data and simplify the data schema
# 4. Persist the simplified version of data
# 5. Read the data from storage

# %%
import pyspark.pandas as ps
import pandas as pd
import json
from pyspark.sql.functions import explode

# %% [markdown]
# ## 1. Create Test Data with complex json nested structure
# ***

# %%
# create payloads 
payload1 = {"EmpId": "A01", "IsPermanent": True, "Department": [{"DepartmentID": "D1", "DepartmentName": "Data Science"}]}
payload2 = {"EmpId": "A02", "IsPermanent": False, "Department": [{"DepartmentID": "D2", "DepartmentName": "Application"}]}
payload3 = {"EmpId": "A03", "IsPermanent": True, "Department": [{"DepartmentID": "D1", "DepartmentName": "Data Science"}]}
payload4 = {"EmpId": "A04", "IsPermanent": False, "Department": [{"DepartmentID": "D2", "DepartmentName": "Application"}]}

# create data structure
data =[
  {"EventID": 1, "Payload": payload1},
  {"EventID": 2, "Payload": payload2},
  {"EventID": 3, "Payload": payload3},
  {"EventID": 4, "Payload": payload4}
]

# %% [markdown]
# ## 2. Get data to the spark dataframe
# ***

# %%
# dump data to json 
jsonData = json.dumps(data)

# append json data to list 
jsonDataList = []
jsonDataList.append(jsonData)

# parallelize json data
jsonRDD = sc.parallelize(jsonDataList)

# store data to spark dataframe 
df = spark.read.json(jsonRDD)

# Show data
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EventID</th><th>Payload</th></tr></thead><tbody><tr><td>1</td><td>List(List(List(D1, Data Science)), A01, true)</td></tr><tr><td>2</td><td>List(List(List(D2, Application)), A02, false)</td></tr><tr><td>3</td><td>List(List(List(D1, Data Science)), A03, true)</td></tr><tr><td>4</td><td>List(List(List(D2, Application)), A04, false)</td></tr></tbody></table></div>

# %% [markdown]
# ### 2.1 Check original data schema
# ***

# %%
df.printSchema()
# Out:
# root
#  |-- EventID: long (nullable = true)
#  |-- Payload: struct (nullable = true)
#  |    |-- Department: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- DepartmentID: string (nullable = true)
#  |    |    |    |-- DepartmentName: string (nullable = true)
#  |    |-- EmpId: string (nullable = true)
#  |    |-- IsPermanent: boolean (nullable = true)

# %% [markdown]
# ### 2.2 Explode data to make data schema simple
# ***

# %%
df1 = df.selectExpr("EventID", "Payload.EmpId", "Payload.IsPermanent","explode(Payload.Department) as Department")
df1.printSchema()
# Out:
# root
#  |-- EventID: long (nullable = true)
#  |-- EmpId: string (nullable = true)
#  |-- IsPermanent: boolean (nullable = true)
#  |-- Department: struct (nullable = true)
#  |    |-- DepartmentID: string (nullable = true)
#  |    |-- DepartmentName: string (nullable = true)

# %% [markdown]
# ### 2.3 Further simplifies the schema
# ***

# %%
df2 = df1.selectExpr("EventID", "EmpId", "IsPermanent","Department.DepartmentID", "Department.DepartmentName")
df2.printSchema()
# Out:
# root
#  |-- EventID: long (nullable = true)
#  |-- EmpId: string (nullable = true)
#  |-- IsPermanent: boolean (nullable = true)
#  |-- DepartmentID: string (nullable = true)
#  |-- DepartmentName: string (nullable = true)

# %% [markdown]
# ## 3. Save the transformed data to the storage
# ***

# %%
display(dbutils.fs.ls("/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/delta/</td><td>delta/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
tbl_name = "/delta/employee_tbl"

# Perform write operation
(df2.write
  .mode("overwrite")
  .format("delta")
  .option("overwriteSchema", "true")
  .save(tbl_name))

# List all delta tables
display(dbutils.fs.ls("./delta/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/delta/city/</td><td>city/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/delta/diamonds/</td><td>diamonds/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/delta/employee_tbl/</td><td>employee_tbl/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# display data inside the employee_tbl
display(spark.read.load("/delta/employee_tbl"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmpId</th><th>IsPermanent</th><th>DepartmentID</th><th>DepartmentName</th></tr></thead><tbody><tr><td>A01</td><td>true</td><td>D1</td><td>Data Science</td></tr><tr><td>A02</td><td>false</td><td>D2</td><td>Application</td></tr><tr><td>A03</td><td>true</td><td>D1</td><td>Data Science</td></tr><tr><td>A04</td><td>false</td><td>D2</td><td>Application</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("./delta/employee_tbl/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/delta/employee_tbl/_delta_log/</td><td>_delta_log/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/delta/employee_tbl/part-00007-b9d7dc6c-8abe-457b-bead-90cb0bf0d630-c000.snappy.parquet</td><td>part-00007-b9d7dc6c-8abe-457b-bead-90cb0bf0d630-c000.snappy.parquet</td><td>1435</td><td>1679536133000</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("./delta/employee_tbl/_delta_log"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/delta/employee_tbl/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>2738</td><td>1679536137000</td></tr><tr><td>dbfs:/delta/employee_tbl/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>1748</td><td>1679536134000</td></tr></tbody></table></div>

# %%
dbutils.fs.rm("./delta/employee_tbl/",True)
# Out:
# Out[54]: True
